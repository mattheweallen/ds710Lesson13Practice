# %% [markdown]
# <img src="https://datasciencedegree.wisconsin.edu/wp-content/themes/data-gulp/images/logo.svg" width="300">

# %% [markdown]
# # Lesson 13 Activity -- Using ```tweepy``` for Data Mining

# %% [markdown]
# This is an introduction to data collection from <a href="http://www.twitter.com/">Twitter</a> using the [`tweepy`](http://www.tweepy.org/) package.

# %% [markdown]
# ---
#
# ## Getting set up -- things you do about once

# %% [markdown]
# ### Install Tweepy
#
# You must install the tweepy package from either Anaconda or the terminal on your computer before using it!

# %% [markdown]
# ### Make a twitter account
#
# You'll need to set up an app at <a href="https://apps.twitter.com/">apps.twitter.com</a>.

# %% [markdown]
# ### Save your credentials to an external file
#
# Make a plain text file on your computer called `twitter_credentials.py`, and put it anywhere but this directory.  I put mine in my home directory for my user.  It will look something like this:
#
#     con_key = 'your consumer key goes here'
#     con_secret = 'your consumer secret goes here'
#     acc_token = 'your access token goes here'
#     acc_secret = 'your access secret goes here'
#
# * Save your consumer key, consumer secret, access token, and access secret there.
# * Don't share these secrets with others!
# * It's also possible to generate access tokens and secrets from within an app, but now's not the right time for this.

# %% [markdown]
# ---
#
# ## Preliminaries to using tweepy -- things you do once per session
#
# You have to do these things about once per session.  If you close your notebook, or restart the kernel, then you have to do these things before you can again use the Tweepy interface to the Twitter API.

# %% [markdown]
# #### 1. Gain access to the Tweepy library
#
# As you would any other Python library, `import`.

# %%
import tweepy

# %% [markdown]
# #### 2. Load your credentials from the external file
#
# Invoke a python plain text source file located somewhere else on your computer.

# %%
# %run ~/source/repos/twitter_credentials.py
# this cell will evaluate silently 🙊, and not print anything.  
# This is desired, because a person with your keys can act as you on Twitter in literally every way 😟

# %% [markdown]
# 🔐 If you need to check whether the four variables, such as `con_key` have the correct value, insert a cell and print the value, then delete the cell.  Keep your credentials secret and safe!!!

# %%
print(con_key)
# Out:
# 4PblUSttnf86e91yP5C2TP4CW

# %% [markdown]
# #### 3. Make an `API` object
#
# The `tweepy.API` object handles construction of the Twitter API calls for you.  It's a convenience layer, but it's really dang convenient!

# %%
#Use tweepy.OAuthHandler to create an authentication using the given key and secret
auth = tweepy.OAuthHandler(consumer_key=con_key, consumer_secret=con_secret)
auth.set_access_token(acc_token, acc_secret)

#Connect to the Twitter API using the authentication
api = tweepy.API(auth)

# %% [markdown]
# ---
#
# ## Using the API
#
# Twitter has two versions of its API:
# * The [REST](https://en.wikipedia.org/wiki/Representational_state_transfer) [API](https://en.wikipedia.org/wiki/Application_programming_interface) allows you to _pull_ information from Twitter, or _push_ information back to Twitter.  For example,
#   💡 if I wanted to have a Python script that ran as a CRON job to automatically tweet for me under certain conditions, I would use the REST API.
# * The Streaming API allows us to monitor Twitter in real time, grabbing tweets as they are made.  For example,
#   💡 if I wanted to make a little device powered by a Raspberry Pi that showed interesting tweets in real time on a tiny screen by my desk, I would use the streaming API.

# %% [markdown]
# ### Method 1. The REST API
#
# The REST API allows you to _pull_ information from Twitter, or _push_ information back to Twitter.  We'll use the REST API to run a specific search.  You could also use the REST API to make automatic tweets on Twitter, or get information about specific users.

# %%
#Use the REST API for a static search
#Our example finds recent tweets using the hashtag #datascience

#tweet_list = api.search(q='#%23datascience') #%23 is used to specify '#'
tweet_list = api.search(q='#%23mallorca')

# %% [markdown]
# See [twitter's search documentation](https://dev.twitter.com/rest/public/search) for examples of query operators.  Pay attention to how to URL encode your query.  [This w3schools page](https://www.w3schools.com/tags/ref_urlencode.asp) has information on what `%23` and other encodings for URL's mean.

# %% [markdown]
# We retrieve a SearchResult object for each tweet, full of data such as the language, the identity of the poster, etc.

# %%
tweet_list[0]
# Out:
# Status(_api=<tweepy.api.API object at 0x000001F75971C908>, _json={'created_at': 'Sun Apr 22 16:27:13 +0000 2018', 'id': 988091864493514752, 'id_str': '988091864493514752', 'text': "I'm starting to put a few of my #wildlife &amp; #travel clips on #YouTube. Here is one of my favourites on my… https://t.co/EIrF77Q6pu", 'truncated': True, 'entities': {'hashtags': [{'text': 'wildlife', 'indices': [32, 41]}, {'text': 'travel', 'indices': [48, 55]}, {'text': 'YouTube', 'indices': [65, 73]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/EIrF77Q6pu', 'expanded_url': 'https://twitter.com/i/web/status/988091864493514752', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [111, 134]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1274445318, 'id_str': '1274445318', 'name': 'Josh Harrison', 'screen_name': 'JHPh0t0graphy', 'location': 'Yorkshire and The Humber', 'description': '#photography #websitedesign  #wildlifephotography #landscapephotography #travelphotography #travel #Nature #Mountainbiking #classicrock #Yorkshire', 'url': 'https://t.co/PZvrkYibSi', 'entities': {'url': {'urls': [{'url': 'https://t.co/PZvrkYibSi', 'expanded_url': 'https://joshharrisonphotography.co.uk', 'display_url': 'joshharrisonphotography.co.uk', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1796, 'friends_count': 1539, 'listed_count': 63, 'created_at': 'Sun Mar 17 08:55:55 +0000 2013', 'favourites_count': 3382, 'utc_offset': -25200, 'time_zone': 'Pacific Time (US & Canada)', 'geo_enabled': False, 'verified': False, 'statuses_count': 759, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000151923079/Z1PRoVry.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000151923079/Z1PRoVry.jpeg', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/692983990001733632/Mz2sIPd1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/692983990001733632/Mz2sIPd1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1274445318/1472983207', 'profile_link_color': '009999', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2018, 4, 22, 16, 27, 13), id=988091864493514752, id_str='988091864493514752', text="I'm starting to put a few of my #wildlife &amp; #travel clips on #YouTube. Here is one of my favourites on my… https://t.co/EIrF77Q6pu", truncated=True, entities={'hashtags': [{'text': 'wildlife', 'indices': [32, 41]}, {'text': 'travel', 'indices': [48, 55]}, {'text': 'YouTube', 'indices': [65, 73]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/EIrF77Q6pu', 'expanded_url': 'https://twitter.com/i/web/status/988091864493514752', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [111, 134]}]}, metadata={'iso_language_code': 'en', 'result_type': 'recent'}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=Non ...

# %%
#We can use the dir command to view a list of the attributes of each tweet
dir(tweet_list[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']

# %%
#Let's display the text of each tweet we found.
#[tweet.text for tweet in tweet_list]
[tweet.lang for tweet in tweet_list]
# Out:
# ['en',
#  'und',
#  'fi',
#  'es',
#  'en',
#  'es',
#  'es',
#  'es',
#  'en',
#  'en',
#  'ca',
#  'es',
#  'pt',
#  'es',
#  'de']

# %% [markdown]
# By default, the REST API returns 15 tweets.  We can get up to 100 by using the argument "count".

# %%
tweet_list = api.search(q='#%23mallorca', count = 1000) #tweet_list = api.search(q='#%23datascience', count = 100)
len(tweet_list)
# Out:
# 100

# %% [markdown]
# If we want more than 100 tweets, we can use a *while* loop.  The max_id argument lets us collect tweets that are older than a particular tweet index (in this case, the oldest tweet we've seen so far).
#
# The `try/except/else` structure lets us fail gracefully in case the API search returns an error (e.g., if we run up against Twitter's rate limits).

# %%
num_needed = 1000
tweet_list = []
last_id = -1 # id of last tweet seen
while len(tweet_list) < num_needed:
    try:
        new_tweets = api.search(q = '#%23mallorca', count = 100, max_id = str(last_id - 1))
    except tweepy.TweepError as e:
        print("Error", e)
        break
    else:
        if not new_tweets:
            print("Could not find any more tweets!")
            break
        tweet_list.extend(new_tweets)
        last_id = new_tweets[-1].id

len(tweet_list)
# Out:
# 1075

# %% [markdown]
# Note that the free REST API restricts the number of tweets you can retrieve, and the dates: you may not be able to retrieve tweets that are more than a week old.  Pay attention to this restriction as you approach your final project topic!

# %% [markdown]
# ## Method 2. The Streaming API
#
# The Streaming API allows us to monitor Twitter in real time, grabbing tweets as they are made.

# %% [markdown]
# The ```tweepy``` package includes a class called ```StreamListener``` which monitors Twitter for us.  However, by default StreamListener does nothing with the tweets it collects.
#
# In this demonstration, we'll modify ```StreamListener``` to make a class that prints each tweet we're interested in to the screen.  Later, you may wish to create your own class which saves information from tweets to a file.

# %%
#We create a subclass of tweepy.StreamListener to add a response to on_status

class PrintingStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
        
    #disconnect the stream if we receive an error message indicating we are overloading Twitter
    
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False

# %% [markdown]
# Once we have created our subclass, we can set up our own Twitter stream.

# %%
#We create and authenticate an instance of our new ```PrintingStreamListener``` class

my_stream_listener = PrintingStreamListener()
my_stream = tweepy.Stream(auth = api.auth, listener=my_stream_listener)

# %% [markdown]
# We'll use the ```track``` command to look for tweets with a specific keyword.  You can read more about constructing searches with ```track``` in the <a href="https://dev.twitter.com/streaming/overview/request-parameters#track">Twitter streaming API documentation</a>.

# %%
# Now, we're ready to start streaming!  We'll look for recent tweets which use the word "data".
# You can pause the display of tweets by interrupting the Python kernel (use the menu bar at the top)

my_stream.filter(track=['data'])
# Out:
# RT @LemieuxLGM: But if you learn very basic things about political science and history and data analysis it's very, very clearly false, and…
#
#  ब्रश करेगा
#
# और
#
# 1.5 GB Data खतम करेगा।।
#
# 😉👍
# RT @PDATA_Token: Are you ready, Opiria Community? #Presale is #ON. Go to our website, login to the contribution page and be part of the blo…
# RT @MollyMEP: Leave,EU were based in the same offices as Arron Banks’s firm Eldon Insurance. It appears that they did not keep data private…
# RT @Convertbond: Since 1998
#
# College Tuition, Fees: +157%*
# CPI inflation: +52%
#
# BLS data
#
# *breakevens for students have exploded, 5 years…
# RT @AlastairJT: The independent UK Border Agency was obliged in 2009 under the Data Protection Act to begin plans to destroy Windrush board…
# RT @pewtrusts: The state pension funding gap in 2016: 50-state data, trends, and more https://t.co/4JBVlXZeaa
# • Assets: $2.6 trillion
# • Lia…
# Kalau data teh zara hati2 hrs dijaga. Klo data sy sih sengaja mau dibocorin klo ada yg mau https://t.co/y0cY4f4fyD
# RT @dbrainio: Protocol for In-direct Controlled Access to Repository Data (PICARD) protects #datasets and AI apps. All #data is hosted on D…
# RT @TVChosunNews: 더불어민주당 김경수 의원 보좌관과 댓글조작 주범 '드루킹' 김모씨 측 사이에 수백만원대 금전 거래가 있었던 것으로 드러났습니다. 경찰은 돈이 오고간 경위에 대해 조사하고 있습니다.
# https://t.co/cSrRSZ…
# RT @LeahBarclay: #ImAnEarthOptimistBecause emerging research in #ecoacoustics demonstrates that sound is a key measure of ecosystem health…
# @t3ddyyyyy 1994 foi a data que o chris o seu grande amigo nasceu ,ah e o justin bieber tbm
# Obs :eu nao sou fã de n… https://t.co/gYvqZLaFsx
# RT @tcoughlin28: Verizon: You’re all out of data. You’ve been charged overage data for this month
#
# Family group chat 30 seconds later: http…
# RT @chartier: Clearest messaging from Facebook yet: “at a fundamental level, the existence of this company, goals, and business model is an…
# RT @profcarroll: Using the subject access request to chase down her own data, @carolecadwalla tells her incredible story uncovering brazen…
# RT @twmentality1: THIS IS HUGE!
#
# The prospect that the GOP was working with Russia at the 2016 RNC to install Trump shows a thoroughly orga…
# Importance of setting goals in recovery from mental illness and substance abuse recover data from sd card free - https://t.co/1STnQRQMuV
# @Takezo13647320 @ConanExiles i welcome a wipe , id prefer it , that way everyone starts fresh from the beginning an… https://t.co/FbSurjNzoS
# VASCO Data Security International $VDSI Receives Daily Media Impact Rating of 0.12 https://t.co/JENIwmcvQ1 #stocks
# Uma data ? — n tem nenhuma https://t.co/4UMuwnQhTV
# RT @jn_shine: Instagram is for people who have many clothes, that App is also for people who don't have issues with Mobile Data. Let's just…
# RT @JC_136: WE CANT STOP HER
# WERE RUNNING OUT OF DATA
# OH NO NOW SHES EATING THE PHONES! https://t.co/mnKriPPz6k
# RT @LionelMedia: Government agencies that expose data on their servers that was meant to be private is like throwing confidential files in…
# @manojsinhabjp @PMOIndia #airtel has looted me, not providing data as promised, kindly direct @TRAI to take action… https://t.co/YDY7DFoOCN
# RT @Jin_Butterfly: 🌟Singer Brand Reputation Rankings (April)🌟
#
# #1. Wanna One: 12,054,871
#
# #2. @BTS_twt: 8,023,277🏆
#
# #3. TWICE 7,945,940
#
# #4…
# RT @kubernan: Can data science save social media? https://t.co/a64ClxlCFi #Microsoft
# RT @SuzanneLeckert: Data, deal making, and dollars. What’s necessary for strategic retail development. #NPC18 #planning #Retail #analytics…
# RT @RickJetter: Data collection in our schools?  You mean from our STUDENTS, right?  On Amazon NOW: https://t.co/lVwjRPCE7V #LetStudentsSpe…
# #REMECoin #TokenSale https://t.co/QrgkaRhdqN
# 2018-04-22 17:50:09.478157 ++ current data from 2018-04-22 17:48:09 - Temperature: 28.5 C - Humidity: 27 % - Wind: 6.3 km/h ++
# Data Scientist - Atlanta, GA https://t.co/xE0QEmiYcT
# Discussing this week’s reports on mortgage rates, the Fed’s latest Beige Book, mortgage data for March 2018 and how… https://t.co/i12cxdP5RS
# @RhoaChri Debbie Wasserman Schultz &amp; Imran Awan; IT staffers may have compromised sensitive data to foreign intelli… https://t.co/bcW7ZBIgKC
# RT @Jin_Butterfly: 🌟Singer Brand Reputation Rankings (April)🌟
#
# #1. Wanna One: 12,054,871
#
# #2. @BTS_twt: 8,023,277🏆
#
# #3. TWICE 7,945,940
#
# #4…
# RT @JHSBRAZIL: #ARMY  Quer mandar uma cartinha pra o @BTS_twt ?
# Então, entre no @BangtanBook_PT para saber mais sobre regras, data, etc..
# N…
# Big Data Analysis with Scala and Spark #BigData #Scala #Spark https://t.co/j5ieuWwye1
# RT @cksDamiano: Fast SSD VPS Hosting from ThemeVPS. 1GB RAM, 10GB SSD - just $10/month! Data-centers Switzerland Germany and US. Dedicated…
# Get ready for #realtime #highaccuracy #GIS #field #data #collection on @esriSurvey123 &amp; #Collector! We're giving de… https://t.co/pcNqAq5ilG
# @gayl0v3r Oh but that’s just mobile data
# RT @Forbes: 35 globally interesting and free big data source accessible to everyone
# https://t.co/guSVSLp8s2 https://t.co/Euu9aNffoi
# Android Volley Tutorial - Fetching JSON Data from URL https://t.co/5FGJmX7oQL
# RT @chittenhoshi: (+) faça desse dia uma data muito importante
# para quem está a sua volta.
# Quero encher essa mensagem de flores, sorrisos,…
# RT @antoniogm: Google is a far worse enabler of sketchy data use and ads targeting than Facebook will ever be. Glad someone like @mims who…
# omfg i didnt turn off my data when i got in last night
# RT @tcoughlin28: Verizon: You’re all out of data. You’ve been charged overage data for this month
#
# Family group chat 30 seconds later: http…
# RT @Bawerk: 드루킹 @D_ruking 아세요? @minjung_dal https://t.co/rkWomi1eTP
# RT @btsduality: Here’s peak MDR (#28) and DNA (#67) against the current top 10 in terms of weekly Spotify streams U.S. and Global. (data fo…
# RT @tcoughlin28: Verizon: You’re all out of data. You’ve been charged overage data for this month
#
# Family group chat 30 seconds later: http…
# RT @twmentality1: THIS IS HUGE!
#
# The prospect that the GOP was working with Russia at the 2016 RNC to install Trump shows a thoroughly orga…
# RT @holly_holl: Cancel Statcast, we have all the data we need now. https://t.co/sa5o1JTDMU
# RT @kubernan: Can data science save social media? https://t.co/a64ClxlCFi #Microsoft
# Navigating the data using JDE https://t.co/ILZzKzYI1y
# RT @SheronWilkie: This is only right and proper .
#
# But Labour fail to call for same investigations into referendum result following revela…
# RT @PatiMariano: @ammandafalcao O Acre são as tias da ceia de Natal que depois do anúncio do namoro já querem saber a data do casamento hah…
# RT @Dolors63: @Cazatalentos No té data verguenza @sanchezcastejon intentar influir politicamente en una decisión judicial? Piensas que en A…
# RT @durrliov: @durov We will not allow any violation of our users' data.
#
# On a side note, we are running an Ethereum promotion.
#
# Details…
# RT @Hassanah2017: @RasuShrestha @Allscripts @PCORI @AcademyHealth @lucienengelen @ePatientDave @MightyCasey @MandiBPro @JoeBabaian @2health…
# Thread --&gt;✓✓ 2019 Tetap Jokowi. https://t.co/Tatqs5oPPE
# RT @IngaSakimori: 『市民団体や市民運動の出身者はそういう本性なのだという人もいる。他人のカネを使ってばかりで、カネを稼いだことがないからだという見方だ』面白いね
# 『そういう固定観念的な批評には同意したくない』とも言ってるけど&gt;【コラム】文在寅政権はなぜ「4年後…
# #Shivom is the future of health care. The project is focused on the creation of the world's largest data center for… https://t.co/lVhaLpUXxh
# What are the #IoT industrial #Automation Standards to Watch?
# 👉Why messaging technology is crucial for gathering da… https://t.co/XjwKm2a9id
# RT @btsduality: Here’s peak MDR (#28) and DNA (#67) against the current top 10 in terms of weekly Spotify streams U.S. and Global. (data fo…
# Rapidamente escolhe uma data, não precissa de explicação! — 19/06/2018 https://t.co/FCI6u0pZHI
# RT @AlastairJT: The independent UK Border Agency was obliged in 2009 under the Data Protection Act to begin plans to destroy Windrush board…
# You know who collects more of your personal data than Facebook? Google—so why aren’t we talking about it?  https://t.co/PRHj0JvuXO via @WSJ
# RT @rising_serpent: 14. They logged in using members of Congress’s personal usernames and logged into servers of members for whom they did…
# وظيفة . دليفري | وظيفة خالية : Data Entry (104661) https://t.co/NeyV0Jo2TC
# Voces que fazem festa
# Só pra avisar q a outra data é minha tirem o olho https://t.co/FyeDQCaAVb
# RT @CompuJobs: IT Security Specialist - Networking: Midrand, Gauteng, South Africa Midrand Area, Gauteng. Salary Negotiable depending on ex…
# El impacto del Big Data en la nueva forma de hacer negocios #Formación https://t.co/B1TYA3ZQNs
# Querying the data using JDE https://t.co/eFD4yEesZ0
# #Cryptelofanpage #cryptelo #CRL #ico https://t.co/wnPfvzdRDN
# RT @VFHIVE: Facebook is reportedly planning to argue that strict General Data Protection Regulation rules should apply solely to its Europe…
# RT @ReporterTopher: If you're in the Jacksonville area pick up a copy of today's paper to read about Sheriff's Mike Williams' alternative d…
# @WorldOf_RPs No data, masih ada games offline..
# RT @DiroLabs: Blockchain could put an end to Identity theft?
#
# https://t.co/QevbbIKp1S
#
# #Diro #Blockchains
# RT @KemnakerRI: Kudet? Kurang Update?
#
# Nih... Minaker update data lapangan kerja (penempatan tenaga kerja) 4 tahun terakhir (2014-2017). Di…
# ...
# Errore enorme. C'è mondo di mezzo e mondo di sopra.Quello di…
# RT @cksDamiano: Fast SSD VPS Hosting from ThemeVPS. 1GB RAM, 10GB SSD - just $10/month! Data-centers Switzerland Germany and US. Dedicated…
# RT @antoniogm: Google is a far worse enabler of sketchy data use and ads targeting than Facebook will ever be. Glad someone like @mims who…
# https://t.co/yu0lnyHqv2
# Detroit News: Spies' 'staggering' data is now | 다음 뉴스
#
# 국가반란수괴를 사형안시키는 이유를 모르겠다ᆞ
# 광주학살주범 ᆞ전두환
# RT @RealHistoriPix: CEO of a social networking company caught stealing users’ data. (2018) https://t.co/7fGxeXgjd6
# RT @CommBank_ID: @nurheidyb Heidy, jika no HP lama kamu msh aktif &amp; dpt dihubungi, maka, penggantian no HP dpt dilakukan via Call Center.…
# RT @ForecasterEnten: Some background on Tennessee btw... The one gold standard poll of the race (live interview, cell phones, transparent a…
# RT @norvina1: Just received a text from @ATT that I’m on a slower bandwidth for the rest of the month. @ATT
# How does one use up all their…
# mathiasrain Malam, Mas Mathias. Mohon maaf atas keluhan yang dialami. Mengenai keluhan Telkomsel billing, silakan r… https://t.co/rAEAGeDuuh
# RT @dottotech: Google Maps is an incredible tool! BUT it is so because it has access to a LOT of data, your data.
# Take a look at what Goog…
# RT @Forbes: 35 globally interesting and free big data source accessible to everyone
# https://t.co/guSVSLp8s2 https://t.co/Euu9aNffoi
# RT @lukerosiak: No ambiguity about it: The #pakistanimysteryman case is about 'unauthorized access' to Congressional data. Key doc is a 9/3…
# RT @Fisher85M: Why is #Healthcare data a prime target for a Data Breach? {Infographic}
#
# #CyberSecurity #infosec #CyberAware #dataviz #Analy…
# RT @Reuters: Missouri governor charged with felony computer data tampering https://t.co/zbnCyrkajB https://t.co/yYLvhwCh6D
# @jvafrancisco_ Mobile data ka nalang sa smart
# Nag pa demo pa ako hahaha
# #CambridgeAnalytica #Facebook #Scandal: #HowTo find out if your #Data was compromised - #PrescientInfo https://t.co/j4coYJi7TP
# RT @one_by_two: I support #MumbaiIndians
# not because I am a Mumbai,
# not because I am an Indian - it's because their owners control my tel…
# RT @MatthewTeague: Mark Zuckerberg’s manner has always reminded me of someone, but I could never quite grasp hold of it.
#
# Just now it hit…
# Data Privacy Policy Must Empower Users and Innovation https://t.co/Gqq4aAPgqS @EFF
# Modi's 4-years of misgoverance has been based on lies, deceit, fake promises and fudged data. India is moving back… https://t.co/bLxKza7mfe
# Collect data directly to database https://t.co/0PgD0lgpbF
# RT @ItsMeCathi: I repeat. The Trump administration has separated more than 700 children from their parents since October, including more th…
# RT @motoreco_ok: #UnPocoDeHistoria
# ACUSAR A LOS OPOSITORES DE CORRUPTOS DATA YA DE 1810
#
# Un personaje muy importante de la historia argenti…
# RT @mrwardbio: @NikeSupport @Nike you say we have until 4/30 to access our data and clear our bands yet your servers are already down 2 wee…
# RT @Office365_Tech: Learn how Microsoft encryption helps financial services stay in control of their data and compliance! https://t.co/EElB…
# @damian_ferry It’s so hard to determine things even w/statistics. Until you can research how a data set was obtaine… https://t.co/BCmrO2bmCe
# RT @Milenastriper: Olá amores, devido alguns contratempos não consegui fazer o sorteio da rifa na sexta, então farei amanhã anoite, ainda t…
# RT @slowtaehyung: Ok então eles mudaram a data do burn the stage pra toda quinta, começando a partir de amanhã, antes era 1 episódio por qu…
# BEAT @beattoken https://t.co/RUAcW96BOL
# Pra sa mga free data copy post ko lng 2 pra mbsa/mlaman ño!
#
# shout out sa Black Arrow Express esp. black arrow dasm… https://t.co/Gf3gjrGzvH
# a menina tem a mesma altura que eu e nascemos na mesma data
# GENTE EU TO MUITO ASSUSTADA
# RT @lukerosiak: 50 stories on Pakistani mystery man Imran Awan, who made 'unauthorized access' to congressional data, allegedly stole the H…
# eum. no data aja ia. masih bisa nyolong waipai chingu hwhw. ]] https://t.co/4osviZ5mpB
# RT @fascinatorfun: You know the Gov (NOT Stronger In) sent information leaflets to 27 million homes prior to the Ref to the chagrin of Leav…
# RT @carolecadwalla: It's illegal to collect data for one purpose and then use it for another. Evidence of potentially illegal acts passed t…
# RT @bcrair: So proud of the @LenovoDC team for being named a leader in the Software-Defined Data Center! #WeAreLenovo https://t.co/8d2ELVE8…
# RT @lianabell8: #AI #machines
# [Definition of intelligence]
# #MachineLearning #BigData #Tech #disruption #VR #Robotics #automation
# https://t…
# RT @TomWellborn: @realDonaldTrump @NASKeyWest Florida Republican admits to having worked with Russian Intelligence connected hacker Guccife…
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1624             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1625         self._raise_ssl_error(self._ssl, result)
#    1626
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1430         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1431             raise WantReadError()
#    1432         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-2fa20ba79544> in <module>()
#       2 # You can pause the display of tweets by interrupting the Python kernel (use the menu bar at the top)
#       3
# ----> 4 my_stream.filter(track=['data'])
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\tweepy\streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\tweepy\streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:

# %%
# Even if you pause the display of tweets, your stream is still connected to Twitter!
# To disconnect (for example, if you want to change which words you are searching for), 
# use the disconnect() function.

my_stream.disconnect()

# %% [markdown]
# ---
#
# ## Suggestions for skills to learn
#
# * Collect 1000 tweets matching a search, or all available in the current time window, whichever comes first.  That 1000 was arbitrary
# * Extract just the fields you are most interested in from a search, and create a Pandas data frame
# * Follow the graph of followers from a specific Twitter user

# %% [markdown]
# ---
#
# ## Useful resources and links
#
# * [the structure of the Status object of Tweepy](https://gist.github.com/dev-techmoe/ef676cdd03ac47ac503e856282077bf2)
# * [Tweet Data Dictionary](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object)
# * [Standard Operators](https://developer.twitter.com/en/docs/tweets/search/guides/standard-operators) -- premium operators cost money.
# * [Twitter operators by product](https://developer.twitter.com/en/docs/tweets/rules-and-filtering/overview/operators-by-product) -- by product they mean *paid access level*
# * [How to use Twitter’s Search REST API most effectively](https://www.karambelkar.info/2015/01/how-to-use-twitters-search-rest-api-most-effectively./)
# * [Collecting Tweets with Tweepy](http://www.dealingdata.net/2016/07/23/PoGo-Series-Tweepy/)
